# %%
# !!! THIS IS A RANDOM AHH HELL FILE !!!
# u can try making sensse of it but its a horrible mix of my code, chatgpt code, and random stuff i did to get a clip for the video
# dont waste your time here

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
from tqdm import tqdm
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque
from pyvis.network import Network

# %%
import networkx as nx

# %%
def get_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return [urljoin(url, a['href']) for a in soup.find_all('a', href=True)]

# %%
def bfs_traversal(start_url, num_layers, graph):
    visited = set()
    queue = deque([(start_url, 0)])
    
    while queue:
        url, layer = queue.popleft()
        if layer > num_layers:
            break
        if url not in visited:
            visited.add(url)
            connections = get_links(url)
            for x in connections:
                graph.add_edge(url, x)
                queue.append((x, layer + 1))

# %%
scan_layers = 1
entrance = "https://www.youtube.com/"

# %%
graph = nx.Graph()

# %%
bfs_traversal(entrance, scan_layers, graph)

# %%
seed = 0
pos = nx.spring_layout(graph, seed=seed)

# %%
nx.draw_networkx(graph, with_labels=True, node_size=1)
plt.show()

# %%
def on_node_click(node_id):
    print(f"You clicked on node {node_id}")

# %%
net = Network(notebook=True)

# Add nodes and edges from your graph object
for node in graph.nodes:
    net.add_node(node)
for edge in graph.edges:
    net.add_edge(edge[0], edge[1])

# Show the network
net.show_buttons(filter_=['physics'])
net.show("graph.html")
# Out:
# ...
# graph.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import time
from tqdm import tqdm

# %%
for x in tqdm(range(1000000000)):
    time.sleep(1)

# %%
def on_node_click(node_id):
    print(f"You clicked on node {node_id}")

net.barnes_hut()
net.show("graph.html")
net.show_buttons()
net.set_onclick_function(on_node_click)

# %%
print("mould\nnode\nmould(Clone)\nhttps://www.youtube.com/about/\nmould(Clone)\nhttps://www.youtube.com/about/press/\nmould(Clone)\nhttps://www.youtube.com/about/copyright/\nmould(Clone)\nhttps://www.youtube.com/t/contact_us/\nmould(Clone)\nhttps://www.youtube.com/creators/\nmould(Clone)\nhttps://www.youtube.com/ads/\nmould(Clone)\nhttps://developers.google.com/youtube\nmould(Clone)\nhttps://www.youtube.com/t/terms\nmould(Clone)\nhttps://www.youtube.com/t/privacy\nmould(Clone)\nhttps://www.youtube.com/about/policies/\nmould(Clone)\nhttps://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&amp;utm_source=ythp&amp;utm_medium=LeftNav&amp;utm_content=txt&amp;u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen\nmould(Clone)\nhttps://www.youtube.com/new\n")
